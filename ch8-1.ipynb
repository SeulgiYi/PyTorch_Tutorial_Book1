# %%
# Example 8-1: OpenAI
import gym
from gym.envs.registration import register
register(
    id='FrozenLake-v3',
    entry_point='gym.envs.toy_text:FrozenLakeEnv',
    kwargs={
        'map_name': '4x4',
        'is_slippery': False
    }
)

env = gym.make("FrozenLake-v3")

# start the play
### observation: location on the lake field
### reward: reward after one turn
### done: whether game is ongoing(false)/finished(true)
### info: probability of each action
### action: log of movement 

for i_episode in range(20):
    observation = env.reset()
    for t in range(100):
        env.render()
        action = env.action_space.sample()                  ## random action
        observation, reward, done, info = env.step(action)  ## one turn   
        print(observation, reward, done, info, action)
        
        if done:
            print("Episode finished after {} timesteps". format(t+1))
            break
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
# 1 0.0 False {'prob': 1.0} 2
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 1 0.0 False {'prob': 1.0} 3
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 1 0.0 False {'prob': 1.0} 3
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0 0.0 False {'prob': 1.0} 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 4 0.0 False {'prob': 1.0} 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 8 0.0 False {'prob': 1.0} 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 8 0.0 False {'prob': 1.0} 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 9 0.0 False {'prob': 1.0} 2
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 5 0.0 True {'prob': 1.0} 3
# Episode finished after 9 timesteps
#
# SFFF
# FHFH
# FFFH
# HFFG
# 0 0.0 False {'prob': 1.0} 3
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 1 0.0 False {'prob': 1.0} 2
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 1 0.0 False {'prob': 1.0} 3
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 2 0.0 False {'prob': 1.0} 2
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 3 0.0 False {'prob': 1.0} 2
#   (Right)
# SFFF
# ...

# %%
print(env.observation_space.n)
print(env.action_space.n)
# Out:
# 16
# 4
